# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, BaggingClassifier,AdaBoostClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
letter_df=pd.read_csv("letterRecognition.csv")

# %%
letter_df.head()
# Out:
#   lettr  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 0     T      2      8      3     5      1      8     13      0      6      6
# 1     I      5     12      3     7      2     10      5      5      4     13
# 2     D      4     11      6     8      6     10      6      2      6     10
# 3     N      7     11      6     6      3      5      9      4      6      4
# 4     G      2      1      3     1      1      8      6      6      6      6
#
#    x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 0     10      8      0      8      0      8
# 1      3      9      2      8      4     10
# 2      3      7      3      7      3      9
# 3      4     10      6     10      2      8
# 4      5      9      1      7      5     10

# %%
letter_df.describe()
# Out:
#               x-box         y-box         width         high         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#               x-bar         y-bar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# ...

# %%
letter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
# lettr    20000 non-null object
# x-box    20000 non-null int64
# y-box    20000 non-null int64
# width    20000 non-null int64
# high     20000 non-null int64
# onpix    20000 non-null int64
# x-bar    20000 non-null int64
# y-bar    20000 non-null int64
# x2bar    20000 non-null int64
# y2bar    20000 non-null int64
# xybar    20000 non-null int64
# x2ybr    20000 non-null int64
# xy2br    20000 non-null int64
# x-ege    20000 non-null int64
# xegvy    20000 non-null int64
# y-ege    20000 non-null int64
# yegvx    20000 non-null int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
from scipy.stats import zscore

# %%
#sns.pairplot(letter_df, diag_kind='kde', hue = 'lettr')

# %%
#array=letter_df.values
letter_df.head()
X = array[:,1:15] 
y = array[:,0] 
#y=letter_df[['lettr']]
#X=letter_df[['x-box','y-box','width','high','onpix','x-bar','y-bar','x2bar','y2bar','xybar','x2ybr','xy2br','x-ege','xegvy','y-ege','yegvx']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=123)

# %%
#from scipy.stats import zscore
#X_train=X_train.apply(zscore)
#X_test=X_test.apply(zscore)

# %%
simpleTree = DecisionTreeClassifier(random_state=0)
simpleTree.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
letter_df.head()
feature_importances = simpleTree.feature_importances_
feature_names = letter_df.columns[1:15]
print(feature_names)

k = 8
top_k_idx = feature_importances.argsort()[-k:][::-1]
print(feature_names[top_k_idx], feature_importances)
# Out:
# Index(['x-box', 'y-box', 'width', 'high', 'onpix', 'x-bar', 'y-bar', 'x2bar',
#        'y2bar', 'xybar', 'x2ybr', 'xy2br', 'x-ege', 'xegvy'],
#       dtype='object')
# Index(['x-ege', 'y2bar', 'x2bar', 'xybar', 'xy2br', 'x2ybr', 'y-bar', 'xegvy'], dtype='object') [0.01855628 0.02637046 0.01632049 0.02462426 0.02822698 0.06213213
#  0.08347864 0.103832   0.12926768 0.0992675  0.09155953 0.09178659
#  0.14616401 0.07841344]

# %%
y_pred = simpleTree.predict(X_test)

# %%
simpleTree.score(X_test,y_test)
# Out:
# 0.8322727272727273

# %%
gbmTree = GradientBoostingClassifier()
gbmTree.fit(X_train , y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
admTree=AdaBoostClassifier()
admTree.fit(X_train , y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)

# %%
bgcl = BaggingClassifier(n_estimators=50, max_samples=.7 , oob_score=False)
bgcl = bgcl.fit(X_train , y_train)

# %%
rfTree = RandomForestClassifier(n_estimators=100)
rfTree.fit(X_train , y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
print("simpleTree ", simpleTree.score(X_test,y_test))
print("gbmTree ",gbmTree.score(X_test,y_test))
print("bgcl ", bgcl.score(X_test,y_test))
print("rfTree", rfTree.score(X_test,y_test))
print("Adaboost",admTree.score(X_test,y_test))
# Out:
# simpleTree  0.8322727272727273
# gbmTree  0.8784848484848485
# bgcl  0.9046969696969697
# rfTree 0.9351515151515152
# Adaboost 0.2787878787878788
